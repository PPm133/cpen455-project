# %%
# %load_ext autoreload
# %autoreload 2

# %%
from google.colab import drive
# Mount your google drive to the /content/drive directory.
# This ensures that files changes remain saved in your drive.
drive.mount('/content/drive', force_remount = True)
# Out:
# Mounted at /content/drive

# %%
import os
# Before running this, make sure you put all the project files inside cpen455-project directory in your google drive.
print(os.listdir('/content/drive/MyDrive/cpen455-project'))
assert 'run.sh' in os.listdir('/content/drive/MyDrive/cpen455-project'), "Please copy all the contents of the project into a folder called cpen455-project in your google drive!"
# %cd /content/drive/MyDrive/cpen455-project
# Out:
# ['Copy of Tutorial6-Project Intro.ipynb', '.gitignore', 'layers.py', 'README.md', 'requirements.txt', 'run.sh', 'guidance', 'data', '__pycache__', 'models', 'samples', 'wandb', 'dataset.py', 'utils.py', 'model.py', 'classification_evaluation.py', 'pcnn_train.py', 'generation_evaluation.py']
# /content/drive/MyDrive/cpen455-project

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install -r requirements.txt
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 90.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 28.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 53.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 11.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 6.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 83.8 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
# ...

# %%
# You may import and test your function here as well, but for the final run, make sure you run it via the above command to ensure everything is runnable by us.

# %%
# Run the code
! python pcnn_train.py \
--batch_size 16 \
--sample_batch_size 16 \
--sampling_interval 10 \
--save_interval 5 \
--dataset cpen455 \
--nr_resnet 5 \
--lr_decay 0.999995 \
--max_epochs 10 \
--en_wandb True
# Out:
# {'batch_size': 16,
#  'data_dir': 'data',
#  'dataset': 'cpen455',
#  'en_wandb': True,
#  'load_params': None,
#  'lr': 0.0002,
#  'lr_decay': 0.999995,
#  'max_epochs': 10,
#  'nr_filters': 40,
#  'nr_logistic_mix': 5,
#  'nr_resnet': 5,
#  'obs': (3, 32, 32),
#  'sample_batch_size': 16,
#  'sample_dir': 'samples',
#  'sampling_interval': 10,
#  'save_dir': 'models',
#  'save_interval': 5,
#  'seed': 1,
#  'tag': 'default'}
# wandb: Using wandb-core as the SDK backend.  Please refer to https://wandb.me/wandb-core for more information.
# wandb: (1) Create a W&B account
# wandb: (2) Use an existing W&B account
# wandb: (3) Don't visualize my results
# wandb: Enter your choice: 3
# wandb: You chose "Don't visualize my results"
# wandb: Tracking run with wandb version 0.19.9
# wandb: W&B syncing is set to `offline` in this directory.
# wandb: Run `wandb online` or set WANDB_MODE=online to enable cloud syncing.
# ...

# %%
# !python generation_evaluation.py
# Out:
# /usr/local/lib/python3.11/dist-packages/torch/nn/utils/weight_norm.py:143: FutureWarning: `torch.nn.utils.weight_norm` is deprecated in favor of `torch.nn.utils.parametrizations.weight_norm`.
#   WeightNorm.apply(module, name, dim)
# Label: Class0
# Label: Class1
# Label: Class2
# Label: Class3
# #generated images: 116, #reference images: 519
# ...
# 100% 1/1 [00:00<00:00,  1.38it/s]
# 100% 5/5 [00:02<00:00,  1.70it/s]
# Dimension 192 works! fid score: 21.180456832306987
# Average fid score: 21.180456832306987

# %%
# !python classification_evaluation.py
# Out:
# {'batch_size': 32, 'data_dir': 'data', 'mode': 'validation'}
# /usr/local/lib/python3.11/dist-packages/torch/nn/utils/weight_norm.py:143: FutureWarning: `torch.nn.utils.weight_norm` is deprecated in favor of `torch.nn.utils.parametrizations.weight_norm`.
#   WeightNorm.apply(module, name, dim)
# model parameters loaded
# 100% 17/17 [00:10<00:00,  1.62it/s]
# Accuracy: 0.5799614643545279
